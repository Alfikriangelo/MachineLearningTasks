# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
# Transformasi data
transform_cifar10 = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

# %%
# Dataset CIFAR-10
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_cifar10)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_cifar10)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Tentukan device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# CNN Model
class CNN(nn.Module):
    def __init__(self, kernel_size=3, pooling_type='max'):
        super(CNN, self).__init__()
        self.pooling_type = pooling_type

        self.conv1 = nn.Conv2d(3, 32, kernel_size=kernel_size, stride=1, padding=kernel_size // 2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=kernel_size, stride=1, padding=kernel_size // 2)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)  # 8x8 adalah hasil pooling dua kali pada input 32x32
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        if self.pooling_type == 'max':
            x = F.max_pool2d(x, 2)
        elif self.pooling_type == 'avg':
            x = F.avg_pool2d(x, 2)

        x = F.relu(self.conv2(x))
        if self.pooling_type == 'max':
            x = F.max_pool2d(x, 2)
        elif self.pooling_type == 'avg':
            x = F.avg_pool2d(x, 2)

        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
# Fungsi untuk melatih model dengan early stopping
def train_model_with_early_stop(model, optimizer, scheduler, num_epochs=10, patience=5):
    criterion = nn.CrossEntropyLoss()
    train_losses, test_losses, test_accuracies = [], [], []

    best_accuracy = 0.0
    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_losses.append(running_loss / len(train_loader))

        # Evaluasi
        model.eval()
        test_loss, correct = 0.0, 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                test_loss += criterion(output, target).item()
                pred = output.argmax(dim=1, keepdim=True)
                correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        accuracy = correct / len(test_loader.dataset)
        test_accuracies.append(accuracy)

        scheduler.step(test_loss)

        # Early stopping logic
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            patience_counter = 0  # Reset counter if accuracy improves
        else:
            patience_counter += 1

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}, Accuracy: {accuracy:.4f}")

        if patience_counter >= patience:
            print("Early stopping triggered!")
            break

    return train_losses, test_losses, test_accuracies

# %%
# Parameters to Compare
kernel_sizes = [3, 5]
pooling_types = ['max', 'avg']
optimizers_to_compare = {
    'SGD': lambda params: optim.SGD(params, lr=0.01, momentum=0.9),
    'RMSProp': lambda params: optim.RMSprop(params, lr=0.01),
    'Adam': lambda params: optim.Adam(params, lr=0.001)
}
epochs_list = [5, 100]

# %%
# Simpan hasil
results = {}

for kernel_size in kernel_sizes:
    for pooling_type in pooling_types:
        for opt_name, opt_fn in optimizers_to_compare.items():
            for num_epochs in epochs_list:
                print(f"Running for Kernel: {kernel_size}, Pooling: {pooling_type}, Optimizer: {opt_name}, Epochs: {num_epochs}")

                model = CNN(kernel_size=kernel_size, pooling_type=pooling_type).to(device)
                optimizer = opt_fn(model.parameters())
                scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3, verbose=True)

                train_losses, test_losses, test_accuracies = train_model_with_early_stop(
                    model, optimizer, scheduler, num_epochs=num_epochs, patience=5
                )

                key = f"Kernel-{kernel_size}_Pooling-{pooling_type}_Opt-{opt_name}_Epochs-{num_epochs}"
                results[key] = {
                    'train_losses': train_losses,
                    'test_losses': test_losses,
                    'test_accuracies': test_accuracies
                }
# Out:
# Running for Kernel: 3, Pooling: max, Optimizer: SGD, Epochs: 5
# Epoch 1/5, Loss: 1.4140, Test Loss: 0.0011, Accuracy: 0.6013
# Epoch 2/5, Loss: 0.9777, Test Loss: 0.0010, Accuracy: 0.6434
# Epoch 3/5, Loss: 0.7960, Test Loss: 0.0009, Accuracy: 0.7061
# Epoch 4/5, Loss: 0.6590, Test Loss: 0.0009, Accuracy: 0.7080
# Epoch 5/5, Loss: 0.5359, Test Loss: 0.0009, Accuracy: 0.7137
# Running for Kernel: 3, Pooling: max, Optimizer: SGD, Epochs: 100
# Epoch 1/100, Loss: 1.3881, Test Loss: 0.0011, Accuracy: 0.6202
# Epoch 2/100, Loss: 0.9488, Test Loss: 0.0009, Accuracy: 0.6839
# Epoch 3/100, Loss: 0.7651, Test Loss: 0.0009, Accuracy: 0.7024
# Epoch 4/100, Loss: 0.6349, Test Loss: 0.0008, Accuracy: 0.7247
# Epoch 5/100, Loss: 0.5096, Test Loss: 0.0009, Accuracy: 0.7148
# Epoch 6/100, Loss: 0.3919, Test Loss: 0.0009, Accuracy: 0.7203
# Epoch 7/100, Loss: 0.3036, Test Loss: 0.0010, Accuracy: 0.7177
# Epoch 8/100, Loss: 0.2278, Test Loss: 0.0012, Accuracy: 0.7123
# Epoch 9/100, Loss: 0.0753, Test Loss: 0.0012, Accuracy: 0.7436
# Epoch 10/100, Loss: 0.0412, Test Loss: 0.0012, Accuracy: 0.7459
# Epoch 11/100, Loss: 0.0301, Test Loss: 0.0013, Accuracy: 0.7475
# Epoch 12/100, Loss: 0.0235, Test Loss: 0.0013, Accuracy: 0.7468
# Epoch 13/100, Loss: 0.0188, Test Loss: 0.0013, Accuracy: 0.7470
# Epoch 14/100, Loss: 0.0184, Test Loss: 0.0013, Accuracy: 0.7473
# Epoch 15/100, Loss: 0.0180, Test Loss: 0.0013, Accuracy: 0.7479
# Epoch 16/100, Loss: 0.0176, Test Loss: 0.0013, Accuracy: 0.7478
# Epoch 17/100, Loss: 0.0173, Test Loss: 0.0013, Accuracy: 0.7479
# Epoch 18/100, Loss: 0.0172, Test Loss: 0.0013, Accuracy: 0.7478
# Epoch 19/100, Loss: 0.0172, Test Loss: 0.0013, Accuracy: 0.7477
# Epoch 20/100, Loss: 0.0172, Test Loss: 0.0013, Accuracy: 0.7477
# Early stopping triggered!
# Running for Kernel: 3, Pooling: max, Optimizer: RMSProp, Epochs: 5
# Epoch 1/5, Loss: 7.9352, Test Loss: 0.0019, Accuracy: 0.3088
# Epoch 2/5, Loss: 1.9592, Test Loss: 0.0019, Accuracy: 0.3362
# Epoch 3/5, Loss: 1.6915, Test Loss: 0.0018, Accuracy: 0.3739
# Epoch 54/100, Loss: 0.9973, Test Loss: 0.0013, Accuracy: 0.5589
# Epoch 55/100, Loss: 0.9957, Test Loss: 0.0013, Accuracy: 0.5637
# Epoch 56/100, Loss: 0.9897, Test Loss: 0.0013, Accuracy: 0.5618
# Epoch 57/100, Loss: 0.9890, Test Loss: 0.0013, Accuracy: 0.5621
# Early stopping triggered!
# Running for Kernel: 5, Pooling: max, Optimizer: Adam, Epochs: 5
# Epoch 1/5, Loss: 1.3176, Test Loss: 0.0011, Accuracy: 0.6014
# Epoch 2/5, Loss: 0.9465, Test Loss: 0.0010, Accuracy: 0.6667
# Epoch 3/5, Loss: 0.7916, Test Loss: 0.0009, Accuracy: 0.6961
# Epoch 4/5, Loss: 0.6734, Test Loss: 0.0008, Accuracy: 0.7095
# Epoch 5/5, Loss: 0.5746, Test Loss: 0.0009, Accuracy: 0.7120
# Running for Kernel: 5, Pooling: max, Optimizer: Adam, Epochs: 100
# Epoch 1/100, Loss: 1.3001, Test Loss: 0.0010, Accuracy: 0.6421
# Epoch 2/100, Loss: 0.9147, Test Loss: 0.0009, Accuracy: 0.6982
# Epoch 3/100, Loss: 0.7496, Test Loss: 0.0008, Accuracy: 0.7053
# Epoch 4/100, Loss: 0.6202, Test Loss: 0.0008, Accuracy: 0.7281
# Epoch 5/100, Loss: 0.5180, Test Loss: 0.0009, Accuracy: 0.7145
# Epoch 6/100, Loss: 0.4232, Test Loss: 0.0009, Accuracy: 0.7268
# Epoch 7/100, Loss: 0.3400, Test Loss: 0.0011, Accuracy: 0.7131
# Epoch 8/100, Loss: 0.2688, Test Loss: 0.0012, Accuracy: 0.7117
# Epoch 9/100, Loss: 0.1151, Test Loss: 0.0011, Accuracy: 0.7367
# Epoch 10/100, Loss: 0.0786, Test Loss: 0.0012, Accuracy: 0.7356
# Epoch 11/100, Loss: 0.0619, Test Loss: 0.0012, Accuracy: 0.7362
# Epoch 12/100, Loss: 0.0492, Test Loss: 0.0013, Accuracy: 0.7347
# Epoch 13/100, Loss: 0.0360, Test Loss: 0.0013, Accuracy: 0.7380
# Epoch 14/100, Loss: 0.0344, Test Loss: 0.0013, Accuracy: 0.7385
# Epoch 15/100, Loss: 0.0330, Test Loss: 0.0013, Accuracy: 0.7373
# Epoch 16/100, Loss: 0.0318, Test Loss: 0.0013, Accuracy: 0.7381
# Epoch 17/100, Loss: 0.0302, Test Loss: 0.0013, Accuracy: 0.7372
# Epoch 18/100, Loss: 0.0302, Test Loss: 0.0013, Accuracy: 0.7374
# Epoch 19/100, Loss: 0.0299, Test Loss: 0.0013, Accuracy: 0.7376
# Early stopping triggered!
# Running for Kernel: 5, Pooling: avg, Optimizer: SGD, Epochs: 5
# Epoch 1/5, Loss: 1.5193, Test Loss: 0.0013, Accuracy: 0.5446
# Epoch 2/5, Loss: 1.1206, Test Loss: 0.0010, Accuracy: 0.6462
# Epoch 3/5, Loss: 0.9135, Test Loss: 0.0009, Accuracy: 0.6731
# Epoch 4/5, Loss: 0.7563, Test Loss: 0.0009, Accuracy: 0.6986
# Epoch 5/5, Loss: 0.6373, Test Loss: 0.0009, Accuracy: 0.6987
# Running for Kernel: 5, Pooling: avg, Optimizer: SGD, Epochs: 100
# Epoch 1/100, Loss: 1.5360, Test Loss: 0.0013, Accuracy: 0.5366
# Epoch 2/100, Loss: 1.1450, Test Loss: 0.0011, Accuracy: 0.6216
# Epoch 3/100, Loss: 0.9286, Test Loss: 0.0009, Accuracy: 0.6702
# Epoch 4/100, Loss: 0.7777, Test Loss: 0.0009, Accuracy: 0.6922
# Epoch 5/100, Loss: 0.6502, Test Loss: 0.0009, Accuracy: 0.6987
# Epoch 6/100, Loss: 0.5352, Test Loss: 0.0009, Accuracy: 0.7083
# Epoch 7/100, Loss: 0.4364, Test Loss: 0.0010, Accuracy: 0.7085
# Epoch 8/100, Loss: 0.3428, Test Loss: 0.0010, Accuracy: 0.7038
# Epoch 9/100, Loss: 0.2627, Test Loss: 0.0011, Accuracy: 0.7109
# Epoch 10/100, Loss: 0.1011, Test Loss: 0.0011, Accuracy: 0.7314
# Epoch 11/100, Loss: 0.0615, Test Loss: 0.0012, Accuracy: 0.7342
# Epoch 12/100, Loss: 0.0463, Test Loss: 0.0013, Accuracy: 0.7355
# Epoch 13/100, Loss: 0.0370, Test Loss: 0.0013, Accuracy: 0.7348
# Epoch 14/100, Loss: 0.0296, Test Loss: 0.0013, Accuracy: 0.7361
# Epoch 15/100, Loss: 0.0287, Test Loss: 0.0013, Accuracy: 0.7366
# Epoch 16/100, Loss: 0.0281, Test Loss: 0.0013, Accuracy: 0.7369
# Epoch 17/100, Loss: 0.0275, Test Loss: 0.0013, Accuracy: 0.7372
# Epoch 18/100, Loss: 0.0269, Test Loss: 0.0013, Accuracy: 0.7370
# Epoch 19/100, Loss: 0.0269, Test Loss: 0.0013, Accuracy: 0.7369
# Epoch 20/100, Loss: 0.0268, Test Loss: 0.0013, Accuracy: 0.7371
# Epoch 21/100, Loss: 0.0267, Test Loss: 0.0013, Accuracy: 0.7370
# Epoch 22/100, Loss: 0.0267, Test Loss: 0.0013, Accuracy: 0.7369
# Early stopping triggered!
# Running for Kernel: 5, Pooling: avg, Optimizer: RMSProp, Epochs: 5
# Epoch 1/5, Loss: 96.1924, Test Loss: 0.0020, Accuracy: 0.2936
# Epoch 2/5, Loss: 2.3621, Test Loss: 0.0023, Accuracy: 0.1058
# Epoch 3/5, Loss: 2.1472, Test Loss: 0.0021, Accuracy: 0.2033
# Epoch 4/5, Loss: 2.5552, Test Loss: 0.0027, Accuracy: 0.1266
# Epoch 5/5, Loss: 1.9956, Test Loss: 0.0019, Accuracy: 0.2838
# Running for Kernel: 5, Pooling: avg, Optimizer: RMSProp, Epochs: 100
# Epoch 1/100, Loss: 27.1123, Test Loss: 0.0020, Accuracy: 0.2940
# Epoch 2/100, Loss: 2.2810, Test Loss: 0.0033, Accuracy: 0.1211
# Epoch 3/100, Loss: 2.6407, Test Loss: 0.0020, Accuracy: 0.2553
# Epoch 4/100, Loss: 2.2006, Test Loss: 0.0020, Accuracy: 0.2552
# Epoch 5/100, Loss: 2.0197, Test Loss: 0.0020, Accuracy: 0.2591
# Epoch 6/100, Loss: 1.8784, Test Loss: 0.0020, Accuracy: 0.2861
# Early stopping triggered!
# Running for Kernel: 5, Pooling: avg, Optimizer: Adam, Epochs: 5
# Epoch 1/5, Loss: 1.3969, Test Loss: 0.0012, Accuracy: 0.5883
# Epoch 2/5, Loss: 1.0285, Test Loss: 0.0010, Accuracy: 0.6536
# Epoch 3/5, Loss: 0.8614, Test Loss: 0.0009, Accuracy: 0.6796
# Epoch 4/5, Loss: 0.7437, Test Loss: 0.0009, Accuracy: 0.6839
# Epoch 5/5, Loss: 0.6555, Test Loss: 0.0009, Accuracy: 0.7017
# Running for Kernel: 5, Pooling: avg, Optimizer: Adam, Epochs: 100
# Epoch 1/100, Loss: 1.3859, Test Loss: 0.0011, Accuracy: 0.6085
# Epoch 2/100, Loss: 1.0054, Test Loss: 0.0010, Accuracy: 0.6554
# Epoch 3/100, Loss: 0.8337, Test Loss: 0.0009, Accuracy: 0.6923
# Epoch 4/100, Loss: 0.7096, Test Loss: 0.0009, Accuracy: 0.7033
# Epoch 5/100, Loss: 0.6107, Test Loss: 0.0009, Accuracy: 0.7123
# Epoch 6/100, Loss: 0.5119, Test Loss: 0.0009, Accuracy: 0.7110
# Epoch 7/100, Loss: 0.4257, Test Loss: 0.0009, Accuracy: 0.7136
# Epoch 8/100, Loss: 0.3510, Test Loss: 0.0011, Accuracy: 0.7059
# Epoch 9/100, Loss: 0.2878, Test Loss: 0.0011, Accuracy: 0.7176
# Epoch 10/100, Loss: 0.1339, Test Loss: 0.0011, Accuracy: 0.7293
# Epoch 11/100, Loss: 0.1009, Test Loss: 0.0012, Accuracy: 0.7307
# Epoch 12/100, Loss: 0.0848, Test Loss: 0.0012, Accuracy: 0.7327
# Epoch 13/100, Loss: 0.0718, Test Loss: 0.0013, Accuracy: 0.7313
# Epoch 14/100, Loss: 0.0563, Test Loss: 0.0013, Accuracy: 0.7333
# Epoch 15/100, Loss: 0.0543, Test Loss: 0.0013, Accuracy: 0.7327
# Epoch 16/100, Loss: 0.0530, Test Loss: 0.0013, Accuracy: 0.7334
# Epoch 17/100, Loss: 0.0517, Test Loss: 0.0013, Accuracy: 0.7328
# Epoch 18/100, Loss: 0.0499, Test Loss: 0.0013, Accuracy: 0.7332
# Epoch 19/100, Loss: 0.0497, Test Loss: 0.0013, Accuracy: 0.7331
# Epoch 20/100, Loss: 0.0495, Test Loss: 0.0013, Accuracy: 0.7331
# Epoch 21/100, Loss: 0.0494, Test Loss: 0.0013, Accuracy: 0.7330
# Early stopping triggered!

# %%
# Visualisasi hasil
for key, result in results.items():
    epochs = range(1, len(result['train_losses']) + 1)
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, result['train_losses'], label='Train Loss')
    plt.plot(epochs, result['test_losses'], label='Test Loss')
    plt.plot(epochs, result['test_accuracies'], label='Test Accuracy')
    plt.title(key)
    plt.xlabel('Epochs')
    plt.ylabel('Metrics')
    plt.legend()
    plt.show()
